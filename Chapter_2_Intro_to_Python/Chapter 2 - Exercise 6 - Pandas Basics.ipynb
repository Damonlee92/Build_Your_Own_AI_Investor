# %% [markdown]
# # Exercise 6 – Pandas Basics

# %%
# Code from Book: Build Your Own AI Investor
# Damon Lee 2020
# Check out the performance on www.valueinvestingai.com
# Code uses data from the (presumably) nice people at https://simfin.com/. 
# Feel free to fork this code for others to see what can be done with it.

# %%
#Import Pandas
import pandas as pd

# %%
#Creating a dictionary with some table data in it.
dict = {
    'Name':['Tom', 'Dick', 'Harry'],
    'Age':[24, 35, 29],
    'Shoe Size':[7,8,9]
}

# %%
#Creating a DataFrame with the data from the dictionary
df=pd.DataFrame(dict)

# %%
#The dataframe can be viewed without the print() command.
df
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %%
#Write the data from the DataFrame to a file
df.to_csv('people.csv')

# %%
# Now I want to read the data, lets create a new DataFrame. Remember to specify an index column!
my_data=pd.read_csv('people.csv', index_col=0)

# %%
#have a look at the data
my_data
# Out:
#     Name  Age  Shoe Size
# 0    Tom   24          7
# 1   Dick   35          8
# 2  Harry   29          9

# %% [markdown]
# # Read in SimFin data

# %%
# Lets read some income statement data from SimFin (https://simfin.com/)
# Your download directory will differ.
Income_Data=pd.read_csv(\
    'C:/Users/G50/Stock_Data/SimFin/us-income-annual/us-income-annual.csv',\
                        delimiter=';')

# %%
# get the DataFrame shape (Might be useful for other computation)
print('DataFrame shape is: ',Income_Data.shape)
#Have a look at what our DataFrame looks like
Income_Data
# You will notice that thefirst few and last few items are shown (Jupyter doesn't want to display all 15,124 rows.)
# Out:
# DataFrame shape is:  (15479, 28)
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 0          A     45846      USD         2008            FY  2008-10-31
# 1          A     45846      USD         2009            FY  2009-10-31
# 2          A     45846      USD         2010            FY  2010-10-31
# 3          A     45846      USD         2011            FY  2011-10-31
# 4          A     45846      USD         2012            FY  2012-10-31
# ...      ...       ...      ...          ...           ...         ...
# 15474    low    186050      USD         2014            FY  2015-02-28
# 15475    low    186050      USD         2015            FY  2016-02-29
# 15476    low    186050      USD         2016            FY  2017-02-28
# 15477    low    186050      USD         2017            FY  2018-02-28
# 15478    low    186050      USD         2018            FY  2019-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 0       2009-01-05    2010-12-20     363000000.0       371000000.0  ...
# 1       2009-12-21    2011-12-16     346000000.0       346000000.0  ...
# 2       2010-12-08    2012-12-20     347000000.0       353000000.0  ...
# 3       2011-12-16    2013-12-19     347000000.0       355000000.0  ...
# 4       2012-12-20    2014-12-22     348000000.0       353000000.0  ...
# ...            ...           ...             ...               ...  ...
# 15474   2015-03-31    2017-04-04     988000000.0       990000000.0  ...
# 15475   2016-03-29    2017-04-04     927000000.0       929000000.0  ...
# 15476   2017-04-04    2017-04-04     880000000.0       881000000.0  ...
# 15477   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
# 15478   2019-03-23    2020-03-23     811000000.0       812000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                       20000000.0            -10000000.0
# 1                      -40000000.0            -59000000.0
# 2                       -6000000.0            -76000000.0
# 3                      -39000000.0            -72000000.0
# 4                      -76000000.0            -92000000.0
# ...                            ...                    ...
# 15474                 -516000000.0           -516000000.0
# 15475                 -552000000.0           -552000000.0
# 15476                 -645000000.0           -645000000.0
# 15477                 -633000000.0           -633000000.0
# 15478                 -624000000.0           -624000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 0                       815000000                      0.0
# 1                         7000000                      0.0
# 2                       560000000              132000000.0
# 3                      1032000000                      NaN
# 4                      1043000000                      NaN
# ...                           ...                      ...
# 15474                  4276000000                      NaN
# 15475                  4419000000                      NaN
# 15476                  5201000000                      NaN
# 15477                  5953000000             -464000000.0
# 15478                  3394000000                      0.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0                 815000000                      -1.220000e+08
# 1                   7000000                      -3.800000e+07
# 2                 692000000                      -8.000000e+06
# 3                1032000000                      -2.000000e+07
# 4                1043000000                       1.100000e+08
# ...                     ...                                ...
# 15474            4276000000                      -1.578000e+09
# 15475            4419000000                      -1.873000e+09
# 15476            5201000000                      -2.108000e+09
# 15477            5489000000                      -2.042000e+09
# 15478            3394000000                      -1.080000e+09
#
#        Income (Loss) from Continuing Operations  \
# 0                                     693000000
# 1                                     -31000000
# 2                                     684000000
# 3                                    1012000000
# 4                                    1153000000
# ...                                         ...
# 15474                                2698000000
# 15475                                2546000000
# 15476                                3093000000
# 15477                                3447000000
# 15478                                2314000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 0                                   NaN   693000000            693000000
# 1                                   NaN   -31000000            -31000000
# 2                                   NaN   684000000            684000000
# 3                                   NaN  1012000000           1012000000
# 4                                   NaN  1153000000           1153000000
# ...                                 ...         ...                  ...
# 15474                               NaN  2698000000           2698000000
# 15475                               NaN  2546000000           2546000000
# 15476                               NaN  3093000000           3093000000
# 15477                               NaN  3447000000           3447000000
# 15478                               NaN  2314000000           2314000000
#
# [15479 rows x 28 columns]

# %%
# The headings of columns are called keys. 
# The columns themselves are called series.
# To see what all the columns are in our dataframe, use the .keys() function. 
print(Income_Data.keys())
# Out:
# Index(['Ticker', 'SimFinId', 'Currency', 'Fiscal Year', 'Fiscal Period',
#        'Report Date', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Research & Development', 'Depreciation & Amortization',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations',
#        'Net Extraordinary Gains (Losses)', 'Net Income',
#        'Net Income (Common)'],
#       dtype='object')

# %%
# To see series data for a single key:
Income_Data['Ticker']
# Out:
# 0          A
# 1          A
# 2          A
# 3          A
# 4          A
#         ...
# 15474    low
# 15475    low
# 15476    low
# 15477    low
# 15478    low
# Name: Ticker, Length: 15479, dtype: object

# %%
Income_Data['Report Date']
# Out:
# 0        2008-10-31
# 1        2009-10-31
# 2        2010-10-31
# 3        2011-10-31
# 4        2012-10-31
#             ...
# 15474    2015-02-28
# 15475    2016-02-29
# 15476    2017-02-28
# 15477    2018-02-28
# 15478    2019-02-28
# Name: Report Date, Length: 15479, dtype: object

# %%
print('The resulting type of object from our series selection is a:', type(Income_Data['Report Date']) )
print('using .values after our selection turns this into a:', type(Income_Data['Report Date'].values) )
# Out:
# The resulting type of object from our series selection is a: <class 'pandas.core.series.Series'>
# using .values after our selection turns this into a: <class 'numpy.ndarray'>

# %%
# To get a list of tickers that exist, we could use the set operations we learned earlier.
my_set = set(Income_Data['Ticker'].values)
print(my_set)
# Out:
# {'FBHS', 'CMCO', 'TSLA', 'EXA', 'AMBA', 'LKSD', 'MTBC', 'AEPI', 'ARNC', 'Mac', 'PLAB', 'VSLR', 'AAPL', 'TESO', 'AGIO', 'MKSI', 'WRI', 'MDXG', 'RIGL', 'AME', 'STRM', 'IPDN', 'RUN', 'AVP', 'FTV', 'ED', 'SORL', 'SANM', 'AXL', 'CALM', 'SRRA', 'CHD', 'WWE', 'TR', 'GLUU', 'USG', 'MICR', 'HCOM', 'SNOW', 'MMI', 'LLL', 'RFP', 'USFD', 'ROP', 'QCOM', 'CME', 'FDX', 'RGLS', 'AEIS', 'MN', 'TMED', 'CAKE', 'CMRO', 'COR', 'DRQ', 'AVGO_old', 'OKTA', 'EPD', 'FET', 'TCMD', 'CRTO', 'O', 'EHTH', 'TMUS', 'SONS', 'PX', 'POST', 'TST', 'AVIR', 'KTWO', 'SE', 'NTRA', 'MSFT', 'GLW', 'KTOS', 'PPL', 'QUOT', 'HUBS', 'KMG', 'INTU', 'RAVE', 'WEN', 'HTGM', 'LNN', 'WYNN', 'MMP', 'UBER', 'CELH', 'MGPI', 'BURL', 'HOG', 'XCRA', 'KWR', 'APU', 'MSM', 'SYNT', 'FEYE', 'BHI', 'IAIC', 'CIK', 'QRVO', 'AC', 'NFLX', 'TRC', 'ESV', 'PINC', 'SCWX', 'YGYI', 'ALNY', 'SGA', 'WBA', 'DSW', 'URBN', 'YOGA', 'STJ', 'NUAN', 'RDFN', 'MSCC', 'GRA', 'AJG', 'MTRN', 'SPG', 'SANW', 'UAL', 'EME', 'PLCE', 'DYNT', 'NTRI', 'SSTK', 'AXGN', 'ETN', 'DY', 'EGLT', 'GPS', 'PSTG', 'TWIN', 'URI', 'BLUE', 'EA', 'ADNT', 'EPAM', 'IFF', 'LL', 'A', 'PANW', 'MSCI', 'TECD', 'BGS', 'M', 'GCI', 'AES', 'ODP', 'HAS', 'LIVN', 'SVU', 'MTD', 'LAKE', 'ADS', 'CSRA', 'FLLZ', 'BTU', 'SUPN', 'CP', 'DPLO', 'DXCM', 'TSS', 'TLRA', 'IDSY', 'ALTR', 'FELE', 'ENDP', 'REN', 'CWEN', 'OMGB', 'PKG', 'SNPS', 'CHEF', 'BLFS', 'CLX', 'ROK', 'PDEX', 'SHOR', 'YUM', 'NDSN', 'CBK', 'FRT', 'ZG', 'SRNE', 'SBGI', 'SITE', 'low', 'RMBL', 'BMRN', 'ADBE', 'MAT', 'NX', 'COP', 'ETR', 'DAL', 'S', 'T', 'PCTI', 'SRPT', 'FOLD', 'HSIC', 'PLNT', 'SHW', 'JAKK', 'OLN', 'ANDX', 'ZGNX', 'JCOM', 'RATE', 'HPE', 'SCSC', 'MNK', 'RKDA', 'AAOI', 'SOLY', 'MXIM', 'GWRS', 'PBYI', 'CPT', 'SWN', 'VRSK', 'SIX', 'GT', 'ESP', 'FMC', 'FORD', 'ADP', 'HDS', 'ANDV', 'ABC', 'ODFL', 'SCOR', 'TLYS', 'DISH', 'SPGI', 'V', 'GDI', 'COKE', 'LII', 'SONO', 'APA', 'SONC', 'MTEM', 'CAL', 'STLR', 'HZO', 'BRKS', 'FIT', 'SPAN', 'HRI', 'CDNS', 'LULU', 'NOV', 'AVAV', 'BFAM', 'OXFD', 'FTI_old', 'VLRX', 'MVIS', 'DE', 'RLJE', 'VEC', 'MAS', 'GEOS', 'ALG', 'ANF', 'NUVA', 'BSTC', 'ZEN', 'ARRS', 'MMEG', 'APD', 'SMG', 'XBIT', 'TYME', 'JCS', 'FSS', 'GRUB', 'VMI', 'JVA', 'BCO', 'STZ', 'TIS', 'CMC', 'WNDW', 'HIL', 'MYGN', 'LCUT', 'GUID', 'PRLB', 'KAR', 'RNG', 'DLB', 'WTS', 'SNH', 'CHE', 'AXTA', 'CARS', 'SD', 'H', 'LPX', 'ES', 'SEAS', 'TIVO', 'MNKD', 'PCRX', 'DIS', 'PHX', 'ACLS', 'WMB', 'MRNA', 'LGCY', 'HSY', 'AMSC', 'HALO', 'EXPD', 'HEI', 'NSPR', 'ROCK', 'AKS', 'ZAYO', 'RSPP', 'HXL', 'TDG', 'SGEN', 'VLGEA', 'TTWO', 'RAVN', 'WBMD', 'TPB', 'WAB', 'IEX', 'SHLD', 'SPNC', 'WNC', 'CETX', 'PKI', 'MON', 'ARG', 'SHAK', 'JNJ', 'AEHR', 'ARA', 'ALXN', 'FPRX', 'BLK', 'CRR', 'BLOX', 'BDX', 'WGL', 'ACLZ', 'R', 'CPRT', 'BOJA', 'AAMC', 'IP', 'WEB', 'CHDN', 'NCR', 'SSNI', 'TDOC', 'MXMG', 'NK', 'SFS', 'VAR', 'LFGR', 'HAYN', 'EXP', 'ESDI', 'SXC', 'CMLS', 'AR', 'CLNT', 'BSPM', 'MLP', 'ETSY', 'IRBT', 'ALT', 'GLP', 'TPIC', 'CUZ', 'CTIC', 'VRTU', 'LQDT', 'PRGB', 'DXC', 'RSYS', 'IEHC', 'SEB', 'SGMA', 'CVGI', 'NE', 'GRMM', 'CNDT', 'CVS', 'ALLE', 'HRS', 'ALEX', 'BPL', 'COVS', 'LOGM', 'ARW', 'ANET', 'WDAY', 'RMCF', 'ULTA', 'EVA', 'MELI', 'PM', 'OFLX', 'SIRI', 'DVAX', 'INGR', 'AMSWA', 'MOS', 'FARM', 'SPPI', 'ABM', 'ATO', 'REAL', 'ARO', 'NOW', 'BHGE', 'SHO', 'TXRH', 'NLSN', 'FTNT', 'CLH', 'BREW', 'EVBG', 'YEXT', 'ARNA', 'CDW', 'LYFT', 'ASNA', 'SURF', 'NSC', 'FOSL', 'PH', 'COT', 'OMI', 'LGIH', 'LABL', 'INT', 'HURN', 'SQBG', 'TCNT', 'ETEC', 'TTC', 'OTEX', 'RAIL', 'COHR', 'KRA', 'EXEL', 'KHC', 'BBSI', 'GILD', 'TGT', 'NTAP', 'IEP', 'DDE', 'MCHP', 'AEO', 'VDSI', 'BRKA', 'PCP', 'SNI', 'Fuel', 'SFLY', 'Golf', 'PGNX', 'EVOP', 'CREE', 'LPTH', 'MBOT', 'NOC', 'PEP', 'REMI', 'FTI', 'TGI', 'GPRE', 'SPLK', 'IMSCQ', 'MTN', 'LAMR', 'RECN', 'WGP', 'CNSL', 'ITRI', 'VAL', 'MAMS', 'QNST', 'MRO', 'ARAY', 'RPM', 'CAH', 'EPE', 'ALRM', 'AAP', 'CBLK', 'PACB', 'BJRI', 'BWXT', 'CKP', 'USCR', 'TXMD', 'CRIS', 'JEC', 'IT', 'WDC', 'GLYC', 'BR', 'INCY', 'TWLO', 'REGN', 'SSP', 'G', 'SHPGF', 'SLG', 'PCMI', 'EGHT', 'NAII', 'INOV', 'ST', 'HSII', 'ALPN', 'UOLI', 'ALSK', ...

# %%
#Alternatively a dataframe has a function .unique()
Income_Data['Ticker'].unique()
# Out:
# array(['A', 'AA', 'AAC', ..., 'ZYNE', 'ZYXI', 'low'], dtype=object)

# %%
# You can use logic on dataframes to obtain a list of boolean values that say whether a rule is True or False for each row.
# Let's try and isolate financial data for the 2017 fiscal period. 
# We will do a boolean check on items in the 'Fiscal Year' column:

IsIt2017 = (Income_Data['Fiscal Year'] == 2017)
print('The boolean logic on the Fiscal Year column is: ', IsIt2017)
# Out:
# The boolean logic on the Fiscal Year column is:  0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15474    False
# 15475    False
# 15476    False
# 15477     True
# 15478    False
# Name: Fiscal Year, Length: 15479, dtype: bool

# %%
# We can use this list of booleans to make a smaller dataframe with only data from fiscal year 2017 as follows:
Income_Data[IsIt2017]
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 13        AA    367153      USD         2017            FY  2017-12-31
# 24       AAL     68568      USD         2017            FY  2017-12-31
# 30      AAMC    847094      USD         2017            FY  2017-12-31
# 40       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 15443   ZUMZ     45730      USD         2017            FY  2018-02-28
# 15452    ZVO    901866      USD         2017            FY  2017-12-31
# 15457   ZYNE    901704      USD         2017            FY  2017-12-31
# 15466   ZYXI    171401      USD         2017            FY  2017-12-31
# 15477    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 13      2018-02-26    2018-02-26     184000000.0       187000000.0  ...
# 24      2018-02-21    2018-02-21     489164000.0       491692000.0  ...
# 30      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 40      2018-03-01    2018-03-01      70837000.0        72121000.0  ...
# ...            ...           ...             ...               ...  ...
# 15443   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 15452   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 15457   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 15466   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 15477   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 13                     -46000000.0           -104000000.0
# 24                    -974000000.0           -959000000.0
# 30                       1086000.0                    0.0
# 40                     -15122000.0            -18703000.0
# ...                            ...                    ...
# 15443                    -357000.0               495000.0
# 15452                    1511000.0                    NaN
# 15457                     810705.0               519554.0
# 15466                   -1450000.0             -1450000.0
# 15477                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 13                     1468000000             -309000000.0
# 24                     3084000000                      NaN
# 30                       -6261000                      0.0
# 40                      257571000              -17994000.0
# ...                           ...                      ...
# 15443                    48403000                      NaN
# 15452                    16619000               -8682000.0
# 15457                   -32012304                      0.0
# 15466                     7494000                      NaN
# 15477                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 13               1159000000                      -6.000000e+08
# 24               3084000000                      -1.165000e+09
# 30                 -6261000                      -7.080000e+05
# 40                239577000                       5.295900e+07
# ...                     ...                                ...
# 15443              48403000                      -2.160100e+07
# 15452               7937000                       1.174000e+06
# 15457             -32012304                       0.000000e+00
# 15466               7494000                      -1.290000e+05
# 15477            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 13                                    559000000
# 24                                   1919000000
# 30                                     -6969000
# 40                                    292536000
# ...                                         ...
# 15443                                  26802000
# 15452                                   9111000
# 15457                                 -32012304
# 15466                                   7365000
# 15477                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 13                                  NaN   217000000            217000000
# 24                                  NaN  1919000000           1919000000
# 30                                  NaN    -6969000             -7175000
# 40                                  NaN   292536000            292536000
# ...                                 ...         ...                  ...
# 15443                               NaN    26802000             26802000
# 15452                               NaN     9111000              9111000
# 15457                               NaN   -32012304            -32012304
# 15466                               NaN     7365000              7365000
# 15477                               NaN  3447000000           3447000000
#
# [1771 rows x 28 columns]

# %%
# Or if we want to do this kind of filter in a single line:
Income_Data[Income_Data['Fiscal Year'] == 2017]
#Which is basically: 'I want the rows of Income_Data where the Income_Data Fiscal Year column is 2017.'
# Notice there are only 1,726 rows instead of 15,125
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 13        AA    367153      USD         2017            FY  2017-12-31
# 24       AAL     68568      USD         2017            FY  2017-12-31
# 30      AAMC    847094      USD         2017            FY  2017-12-31
# 40       AAN    441241      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 15443   ZUMZ     45730      USD         2017            FY  2018-02-28
# 15452    ZVO    901866      USD         2017            FY  2017-12-31
# 15457   ZYNE    901704      USD         2017            FY  2017-12-31
# 15466   ZYXI    171401      USD         2017            FY  2017-12-31
# 15477    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 9       2017-12-21    2018-12-20     322000000.0       326000000.0  ...
# 13      2018-02-26    2018-02-26     184000000.0       187000000.0  ...
# 24      2018-02-21    2018-02-21     489164000.0       491692000.0  ...
# 30      2018-03-01    2018-03-01       1570428.0         1570428.0  ...
# 40      2018-03-01    2018-03-01      70837000.0        72121000.0  ...
# ...            ...           ...             ...               ...  ...
# 15443   2018-03-19    2018-03-19      24679000.0        24878000.0  ...
# 15452   2018-02-21    2019-03-12      32058000.0        32794000.0  ...
# 15457   2018-03-12    2019-03-11      12914814.0        12914814.0  ...
# 15466   2018-02-28    2018-02-28      32156000.0        33196000.0  ...
# 15477   2018-04-02    2018-04-02     839000000.0       840000000.0  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 13                     -46000000.0           -104000000.0
# 24                    -974000000.0           -959000000.0
# 30                       1086000.0                    0.0
# 40                     -15122000.0            -18703000.0
# ...                            ...                    ...
# 15443                    -357000.0               495000.0
# 15452                    1511000.0                    NaN
# 15457                     810705.0               519554.0
# 15466                   -1450000.0             -1450000.0
# 15477                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 13                     1468000000             -309000000.0
# 24                     3084000000                      NaN
# 30                       -6261000                      0.0
# 40                      257571000              -17994000.0
# ...                           ...                      ...
# 15443                    48403000                      NaN
# 15452                    16619000               -8682000.0
# 15457                   -32012304                      0.0
# 15466                     7494000                      NaN
# 15477                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 13               1159000000                      -6.000000e+08
# 24               3084000000                      -1.165000e+09
# 30                 -6261000                      -7.080000e+05
# 40                239577000                       5.295900e+07
# ...                     ...                                ...
# 15443              48403000                      -2.160100e+07
# 15452               7937000                       1.174000e+06
# 15457             -32012304                       0.000000e+00
# 15466               7494000                      -1.290000e+05
# 15477            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 13                                    559000000
# 24                                   1919000000
# 30                                     -6969000
# 40                                    292536000
# ...                                         ...
# 15443                                  26802000
# 15452                                   9111000
# 15457                                 -32012304
# 15466                                   7365000
# 15477                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 13                                  NaN   217000000            217000000
# 24                                  NaN  1919000000           1919000000
# 30                                  NaN    -6969000             -7175000
# 40                                  NaN   292536000            292536000
# ...                                 ...         ...                  ...
# 15443                               NaN    26802000             26802000
# 15452                               NaN     9111000              9111000
# 15457                               NaN   -32012304            -32012304
# 15466                               NaN     7365000              7365000
# 15477                               NaN  3447000000           3447000000
#
# [1771 rows x 28 columns]

# %%
# Let's order the stocks for financial year 2017 by net income.
# Within a DataFrame the rows can be ordered as follows:
Income_Data.sort_values(by=['Net Income'])
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 5887      GE    244314      USD         2018            FY  2018-12-31
# 3428     COP    378120      USD         2008            FY  2008-12-31
# 13379   TEVA    616649      USD         2017            FY  2017-12-31
# 5217       F    249937      USD         2008            FY  2008-12-31
# 2965     CHK    378111      USD         2015            FY  2015-12-31
# ...      ...       ...      ...          ...           ...         ...
# 15245    XOM    121214      USD         2008            FY  2008-12-31
# 76      AAPL    111052      USD         2016            FY  2016-09-30
# 77      AAPL    111052      USD         2017            FY  2017-09-30
# 75      AAPL    111052      USD         2015            FY  2015-09-30
# 78      AAPL    111052      USD         2018            FY  2018-09-30
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 5887    2019-02-26    2019-02-26    8.691000e+09      8.691000e+09  ...
# 3428    2009-02-03    2011-02-23    1.523432e+09      1.523432e+09  ...
# 13379   2018-02-01    2019-02-19    1.016000e+09      1.016000e+09  ...
# 5217    2009-02-05    2011-02-28    2.273000e+09      2.272000e+09  ...
# 2965    2016-02-04    2018-02-22    3.310000e+06      3.310000e+06  ...
# ...            ...           ...             ...               ...  ...
# 15245   2009-02-05    2011-02-28    4.941000e+09      4.961000e+09  ...
# 76      2016-10-26    2018-11-05    5.470820e+09      5.500281e+09  ...
# 77      2017-11-02    2018-11-05    5.217242e+09      5.251692e+09  ...
# 75      2015-10-28    2017-11-03    5.753421e+09      5.793069e+09  ...
# 78      2018-11-05    2018-11-05    4.955377e+09      5.000109e+09  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 5887                 -5.590000e+09          -5.059000e+09
# 3428                  4.263000e+09          -9.350000e+08
# 13379                 3.040000e+08          -8.950000e+08
# 5217                 -8.920000e+09          -9.737000e+09
# 2965                 -4.050000e+08          -3.170000e+08
# ...                            ...                    ...
# 15245                -5.912000e+10          -6.730000e+08
# 76                    1.348000e+09                    NaN
# 77                    2.745000e+09                    NaN
# 75                    1.285000e+09                    NaN
# 78                    2.005000e+09                    NaN
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 5887                   4779000000            -2.491300e+10
# 3428                  31409000000            -3.426900e+10
# 13379                  4295000000            -2.267400e+10
# 5217                 -14895000000                      NaN
# 2965                   -852000000            -1.824600e+10
# ...                           ...                      ...
# 15245                 83397000000                      NaN
# 76                    61372000000                      NaN
# 77                    64089000000                      NaN
# 75                    72515000000                      NaN
# 78                    72903000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 5887           -20134000000                      -5.830000e+08
# 3428            -2860000000                      -1.341900e+10
# 13379          -18379000000                       1.933000e+09
# 5217           -14895000000                       6.200000e+07
# 2965           -19098000000                       4.463000e+09
# ...                     ...                                ...
# 15245           83397000000                      -3.653000e+10
# 76              61372000000                      -1.568500e+10
# 77              64089000000                      -1.573800e+10
# 75              72515000000                      -1.912100e+10
# 78              72903000000                      -1.337200e+10
#
#        Income (Loss) from Continuing Operations  \
# 5887                               -20717000000
# 3428                               -16279000000
# 13379                              -16449000000
# 5217                               -14833000000
# 2965                               -14635000000
# ...                                         ...
# 15245                               46867000000
# 76                                  45687000000
# 77                                  48351000000
# 75                                  53394000000
# 78                                  59531000000
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 5887                      -1.726000e+09 -22354000000         -22801000000
# 3428                                NaN -16349000000         -16349000000
# 13379                               NaN -16265000000         -16525000000
# 5217                       9.000000e+06 -14766000000         -14766000000
# 2965                                NaN -14567000000         -14738000000
# ...                                 ...          ...                  ...
# 15245                               NaN  45220000000          45220000000
# 76                                  NaN  45687000000          45687000000
# 77                                  NaN  48351000000          48351000000
# 75                                  NaN  53394000000          53394000000
# 78                                  NaN  59531000000          59531000000
#
# [15479 rows x 28 columns]

# %%
# However, we wish to perform this for only the 2017 fiscal year. 
# Fortunately you can just put one operations in front of the other as follows:
Income_Data[Income_Data['Fiscal Year'] == 2017].sort_values(by=['Net Income'])
# It looks like AAPL and BRKA earned the most money that year, more than $40bn!
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 13379   TEVA    616649      USD         2017            FY  2017-12-31
# 9316     MRO    378185      USD         2017            FY  2017-12-31
# 513      AGN     61474      USD         2017            FY  2017-12-31
# 6080      GM    125620      USD         2017            FY  2017-12-31
# 4505    DVMT     47385      USD         2017            FY  2018-01-31
# ...      ...       ...      ...          ...           ...         ...
# 9370    MSFT     59265      USD         2017            FY  2017-06-30
# 13225      T     66790      USD         2017            FY  2017-12-31
# 14659     VZ    101219      USD         2017            FY  2017-12-31
# 2289    BRKA     71306      USD         2017            FY  2017-12-31
# 77      AAPL    111052      USD         2017            FY  2017-09-30
#
#       Publish Date Restated Date  Shares (Basic)  Shares (Diluted)  ...  \
# 13379   2018-02-01    2019-02-19    1.016000e+09      1.016000e+09  ...
# 9316    2018-02-22    2018-02-22    8.500000e+08      8.500000e+08  ...
# 513     2018-02-16    2018-02-16    3.338000e+08      3.338000e+08  ...
# 6080    2018-02-06    2018-02-06    1.465000e+09      1.492000e+09  ...
# 4505    2018-03-29    2018-03-29    2.030000e+08      2.030000e+08  ...
# ...            ...           ...             ...               ...  ...
# 9370    2017-07-27    2018-08-03    7.746000e+09      7.832000e+09  ...
# 13225   2018-02-20    2019-02-20    6.164000e+09      6.183000e+09  ...
# 14659   2018-02-23    2018-02-23    4.084000e+09      4.089000e+09  ...
# 2289    2018-02-26    2018-02-26    3.289647e+06      3.289647e+06  ...
# 77      2017-11-02    2018-11-05    5.217242e+09      5.251692e+09  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 13379                 3.040000e+08          -8.950000e+08
# 9316                 -2.700000e+08          -2.700000e+08
# 513                  -4.465200e+09          -1.027900e+09
# 6080                  1.847000e+09          -5.750000e+08
# 4505                 -2.355000e+09                    NaN
# ...                            ...                    ...
# 9370                  8.760000e+08                    NaN
# 13225                -4.703000e+09          -6.300000e+09
# 14659                -6.820000e+09          -4.733000e+09
# 2289                           NaN                    NaN
# 77                    2.745000e+09                    NaN
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 13379                  4295000000            -2.267400e+10
# 9316                   -174000000            -2.800000e+08
# 513                  -10386400000                      NaN
# 6080                  11863000000             0.000000e+00
# 4505                  -5688000000                      NaN
# ...                           ...                      ...
# 9370                  30207000000            -3.060000e+08
# 13225                 18181000000            -2.914000e+09
# 14659                 20594000000                      NaN
# 2289                  20900000000                      NaN
# 77                    64089000000                      NaN
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 13379          -18379000000                       1.933000e+09
# 9316             -454000000                      -3.760000e+08
# 513            -10386400000                       6.670400e+09
# 6080            11863000000                      -1.153300e+10
# 4505            -5688000000                       1.833000e+09
# ...                     ...                                ...
# 9370            29901000000                      -4.412000e+09
# 13225           15267000000                       1.470800e+10
# 14659           20594000000                       9.956000e+09
# 2289            20900000000                       2.151500e+10
# 77              64089000000                      -1.573800e+10
#
#        Income (Loss) from Continuing Operations  \
# 13379                              -16449000000
# 9316                                 -830000000
# 513                                 -3716000000
# 6080                                  330000000
# 4505                                -3855000000
# ...                                         ...
# 9370                                25489000000
# 13225                               29847000000
# 14659                               30550000000
# 2289                                45353000000
# 77                                  48351000000
#
#        Net Extraordinary Gains (Losses)   Net Income  Net Income (Common)
# 13379                               NaN -16265000000         -16525000000
# 9316                      -4.893000e+09  -5723000000          -5723000000
# 513                       -4.029000e+08  -4125500000          -4403900000
# 6080                      -4.212000e+09  -3864000000          -3880000000
# 4505                       0.000000e+00  -3728000000          -3728000000
# ...                                 ...          ...                  ...
# 9370                                NaN  25489000000          25489000000
# 13225                               NaN  29450000000          29450000000
# 14659                               NaN  30101000000          30101000000
# 2289                                NaN  44940000000          44940000000
# 77                                  NaN  48351000000          48351000000
#
# [1771 rows x 28 columns]

# %%
# Lets plot the distribution of net income for all american companies:
Income_Data['Net Income'].hist()

# %%
# Plot graph with just 2017 FY data, logarithmic Y axis and more bins for greater resolution.
from matplotlib import pyplot as plt # Import plotting library
Income_Data[Income_Data['Fiscal Year'] == 2017]['Net Income'].hist(bins=100, log=True)
plt.title('USA Corporate Net Income for 2017 Histogram')
plt.xlabel('Value in USD')
plt.ylabel('Number of Instances')
print('Max value is: ', Income_Data[Income_Data['Fiscal Year'] == 2017]['Net Income'].max())
# Out:
# Max value is:  48351000000

# %%
# Statistical data can be calculated with the dataframe .describe() function
Income_Data.describe()
# Out:
#             SimFinId   Fiscal Year  Shares (Basic)  Shares (Diluted)  \
# count   15125.000000  15125.000000    1.503000e+04      1.503000e+04
# mean   399399.405091   2013.913124    2.324829e+08      2.364339e+08
# std    265720.843594      2.764324    6.077170e+08      6.202862e+08
# min        18.000000   2007.000000    1.400000e+01      1.400000e+01
# 25%    160965.000000   2012.000000    2.673825e+07      2.694063e+07
# 50%    371566.000000   2014.000000    6.677505e+07      6.800000e+07
# 75%    639822.000000   2016.000000    1.930758e+08      1.959935e+08
# max    985521.000000   2018.000000    8.945000e+09      8.996000e+09
#
#             Revenue  Cost of Revenue  Gross Profit  Operating Expenses  \
# count  1.490400e+04     1.377600e+04  1.491100e+04        1.506100e+04
# mean   7.423264e+09    -5.205191e+09  2.611450e+09       -1.656050e+09
# std    2.444919e+10     1.864871e+10  7.904727e+09        4.924203e+09
# min    0.000000e+00    -3.853010e+11 -1.280800e+10       -1.071470e+11
# 25%    2.737512e+08    -3.082569e+09  1.184120e+08       -1.225592e+09
# 50%    1.415794e+09    -7.781640e+08  5.680430e+08       -3.638050e+08
# 75%    5.159512e+09    -1.431200e+08  1.964170e+09       -9.075300e+07
# max    5.144050e+11     3.100000e+07  1.722200e+11        1.110132e+09
#
#        Selling, General & Administrative  Research & Development  ...  \
# count                       1.439500e+04            6.035000e+03  ...
# mean                       -1.135391e+09           -3.959251e+08  ...
# std                         3.947171e+09            1.262572e+09  ...
# min                        -1.071470e+11           -2.141900e+10  ...
# 25%                        -8.121845e+08           -1.890505e+08  ...
# 50%                        -2.090000e+08           -5.279900e+07  ...
# 75%                        -4.737350e+07           -1.464700e+07  ...
# max                         0.000000e+00            6.480000e+05  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# count                 1.496900e+04           1.333000e+04
# mean                 -1.165516e+08          -1.255652e+08
# std                   1.304191e+09           3.399050e+08
# min                  -5.912000e+10          -9.737000e+09
# 25%                  -8.500000e+07          -1.109750e+08
# 50%                  -1.092200e+07          -2.255700e+07
# 75%                  -5.600000e+04          -9.279852e+05
# max                   1.290300e+10           1.537000e+09
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# count                1.512500e+04             1.003700e+04
# mean                 8.106130e+08            -1.294501e+08
# std                  3.113970e+09             9.750515e+08
# min                 -1.489500e+10            -3.426900e+10
# 25%                  1.545000e+06            -4.348600e+07
# 50%                  1.041300e+08            -4.275000e+06
# 75%                  5.261000e+08             0.000000e+00
# max                  8.339700e+10             1.289400e+10
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# count          1.512500e+04                       1.425600e+04
# mean           7.247095e+08                      -2.051242e+08
# std            3.122237e+09                       1.135173e+09
# min           -2.869500e+10                      -3.653000e+10
# 25%           -5.780000e+05                      -1.329012e+08
# 50%            8.409600e+07                      -2.200000e+07
# 75%            4.750000e+08                      -3.997500e+05
# max            8.339700e+10                       3.483100e+10
#
#        Income (Loss) from Continuing Operations  \
# count                              1.512500e+04
# mean                               5.335821e+08
# std                                2.306867e+09
# min                               -2.071700e+10
# 25%                               -9.000000e+05
# 50%                                6.230000e+07
# 75%                                3.559190e+08
# max                                5.953100e+10
#
#        Net Extraordinary Gains (Losses)    Net Income  Net Income (Common)
# count                      3.347000e+03  1.512500e+04         1.512500e+04
# mean                       4.638656e+07  5.266860e+08         5.240174e+08
# std                        5.768440e+08  2.293419e+09         2.292523e+09
# min                       -9.559000e+09 -2.235400e+10        -2.280100e+10
# 25%                       -3.800000e+06 -9.720360e+05        -1.229583e+06
# 50%                        0.000000e+00  6.100000e+07         6.007800e+07
# 75%                        1.700000e+07  3.540000e+08         3.524090e+08
# max                        1.591450e+10  5.953100e+10         5.953100e+10
#
# [8 rows x 22 columns]

# %%
# You can create new dataframes from filtered old dataframes, let's separate the 2017 fiscal year data to a new dataframe.
Income_Data_2017 = Income_Data[Income_Data['Fiscal Year'] == 2017]

# %%
Income_Data_2017.head(9)
# Out:
#    Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9       A     45846      USD         2017            FY  2017-10-31
# 13     AA    367153      USD         2017            FY  2017-12-31
# 24    AAL     68568      USD         2017            FY  2017-12-31
# 34    AAN    441241      USD         2017            FY  2017-12-31
# 41   AAOI    671827      USD         2017            FY  2017-12-31
#
#    Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 9    2017-12-21     322000000.0       326000000.0  4.472000e+09  ...
# 13   2018-02-26     184000000.0       187000000.0  1.165200e+10  ...
# 24   2018-02-21     489164000.0       491692000.0  4.220700e+10  ...
# 34   2018-03-01      70837000.0        72121000.0  3.383708e+09  ...
# 41   2018-02-28      19097355.0        20139105.0  3.823290e+08  ...
#
#     Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                   -38000000.0            -57000000.0
# 13                  -46000000.0           -104000000.0
# 24                 -974000000.0           -959000000.0
# 34                  -15122000.0            -18703000.0
# 41                   -2425000.0              -637000.0
#
#     Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 9                    803000000                      NaN             803000000
# 13                  1468000000             -309000000.0            1159000000
# 24                  3084000000                      NaN            3084000000
# 34                   257571000              -17994000.0             239577000
# 41                    84526000                      NaN              84526000
#
#     Income Tax (Expense) Benefit, Net  \
# 9                       -1.190000e+08
# 13                      -6.000000e+08
# 24                      -1.165000e+09
# 34                       5.295900e+07
# 41                      -1.057500e+07
#
#     Income (Loss) from Continuing Operations  \
# 9                                  684000000
# 13                                 559000000
# 24                                1919000000
# 34                                 292536000
# 41                                  73951000
#
#     Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                NaN   684000000            684000000
# 13                               NaN   217000000            217000000
# 24                               NaN  1919000000           1919000000
# 34                               NaN   292536000            292536000
# 41                               NaN    73951000             73951000
#
# [5 rows x 27 columns]

# %%
Income_Data_2017.tail()
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 15090   ZUMZ     45730      USD         2017            FY  2018-02-28
# 15099    ZVO    901866      USD         2017            FY  2017-12-31
# 15104   ZYNE    901704      USD         2017            FY  2017-12-31
# 15113   ZYXI    171401      USD         2017            FY  2017-12-31
# 15124    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 15090   2018-03-19      24679000.0        24878000.0  9.274010e+08  ...
# 15099   2018-02-21      32058000.0        32794000.0  4.751130e+08  ...
# 15104   2018-03-12      12914814.0        12914814.0  0.000000e+00  ...
# 15113   2018-02-28      32156000.0        33196000.0  2.343200e+07  ...
# 15124   2018-04-02     839000000.0       840000000.0  6.861900e+10  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 15090                    -357000.0               495000.0
# 15099                    1511000.0                    NaN
# 15104                     810705.0               519554.0
# 15113                   -1450000.0             -1450000.0
# 15124                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 15090                    48403000                      NaN
# 15099                    16619000               -8682000.0
# 15104                   -32012304                      0.0
# 15113                     7494000                      NaN
# 15124                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 15090              48403000                      -2.160100e+07
# 15099               7937000                       1.174000e+06
# 15104             -32012304                       0.000000e+00
# 15113               7494000                      -1.290000e+05
# 15124            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 15090                                  26802000
# 15099                                   9111000
# 15104                                 -32012304
# 15113                                   7365000
# 15124                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 15090                               NaN    26802000             26802000
# 15099                               NaN     9111000              9111000
# 15104                               NaN   -32012304            -32012304
# 15113                               NaN     7365000              7365000
# 15124                               NaN  3447000000           3447000000
#
# [5 rows x 27 columns]

# %% [markdown]
# # Exercise 6 - Rudimentary stock filtering with Pandas
# ## Objectives:
# * To take the income statement data and the stock price data to make a rudimentary stock screener for price/earnings, price sales ratios, etc.
# * To view some agregate financial data visually to gain some intuition about the corporations in the stock market.
# * To practice what has been learnt so far in meeting the objectives
#
# ### Some bits of the code are missing, follow through and try and get it working

# %% [markdown]
# ### First lets get the stock data

# %%
#get csv data from simfin.com
import pandas as pd
Income_Data = pd.read_csv('C:/Users/G50/Stock_Data/SimFin/us-income-annual/us-income-annual.csv', delimiter=';')
stock_prices = pd.read_csv('C:/Users/G50/Stock_Data/SimFin/us-shareprices-daily/us-shareprices-daily.csv', delimiter=';')

# %%
# How big are these dataframes? How is the data stored? 
# print out the shape of both dataframes

#print('Income data size is: ', Income_Data.shape)
#print('stock_prices data size is: ', stock_prices.???)

# %%
#print out the keys of the dataframes (which are the column headers)

#print('Income keys are: ', Income_Data.???())
#print('stock_prices keys are: ', stock_prices.keys())

# %%
#Display the first 5 rows of the dataframes

#Income_Data.head(???)

# %%
#stock_prices.head(5)

# %% [markdown]
# ### Make a Market Cap series
# A lot of useful ratios commonly used to analyse companies depend on the Market Capitalization of the company, so we will add this to our dataframe first.
#
# Create a new dataframe which has all the income data as well as a market cap value, which will be the number of shares outstanding multiplied by the stock price.
#
# We will take the stock price at a relevant time for the income statement data, which should be around or just after the fiscal year reporting date.
#
# We will be using a previous fiscal year data for this exercise, where the 'Fiscal Year' series is 2017.

# %%
# See when the reporting data is usually made.
# To view a date in the series as a date object, instead of merely a string, use the pd.to_datetime() function.

# This date data has to be formatted this way for easy histogram plotting.
Income_Data['Publish Date']=pd.to_datetime(Income_Data['Publish Date'])

# Plot a histogram with a large number of bins to get a rough idea of when most reporting is done.
Income_Data[Income_Data['Fiscal Year'] == 2017]['Publish Date'].hist(bins=??)

# %%
# Make a new dataframe of only the income data from 'Fiscal Year' == 2017.
Income_Data_2018 = Income_Data[Income_Data['Fiscal Year'] == 2017]

# %%
# View the series of company tickers that exist for that fiscal year, and see how long the list is.
(Income_Data[Income_Data['Fiscal Year'] == ??]['Ticker']).unique
# Out:
# <bound method Series.unique of 9           A
# 13         AA
# 24        AAL
# 34        AAN
# 41       AAOI
#          ...
# 15090    ZUMZ
# 15099     ZVO
# 15104    ZYNE
# 15113    ZYXI
# 15124     low
# Name: Ticker, Length: 1726, dtype: object>

# %%
# It appears as though most reporting is done just after the beginning of the year for these companies.
# Filter the stock price dataframe for the first of March of that year and make a new dataframe of that data. 
# print out the shape of the new dataframe. and use .head() to see it.

stock_prices_2018 = (stock_prices[stock_prices['Date'] == '2018-03-???'])
print('stock_prices_2018 dataframe shape is: ', stock_prices_2018.shape)
stock_prices_2018.head()
# Out:
# stock_prices_2018 dataframe shape is:  (1901, 10)
#       Ticker  SimFinId        Date     Open       Low      High    Close  \
# 2809    GOOG        18  2018-03-01  1107.87  1067.001  1110.120  1069.52
# 5927    ATVI       243  2018-03-01    73.16    71.520    73.420    72.01
# 9020     BLK       914  2018-03-01   548.60   527.030   549.020   535.58
# 12113   ADBE     14099  2018-03-01   210.32   204.450   210.683   206.03
# 15206    MMM     22219  2018-03-01   236.15   229.530   236.830   231.34
#
#        Adj. Close  Dividend   Volume
# 2809      1069.52       NaN  2515900
# 5927        70.61       NaN  8123915
# 9020       503.36       NaN   779735
# 12113      206.03       NaN  2632200
# 15206      217.24       NaN  3487126

# %%
# Notice the size of the list of tickersin the Income statement dataframe(1726) differs from the share prices dataframe(1901)
# In the real work we frequently deal with imperfect data. We will now cut down the data to make both dataframes correspond
# so that we can add out market cap column.

# %%
# Use the .isin() dataframe function to first cut down the share prices dataframe to only contain stocks that are in the 
# Income statement dataframe.
stock_prices_2018 = stock_prices_2018[stock_prices_2018['Ticker'].isin(Income_Data_2018['Ticker'])]

# See the DataFrame
stock_prices_2018
# Out:
#         Ticker  SimFinId        Date   Open      Low     High  Close  \
# 109399       A     45846  2018-03-01  68.47  66.7900  68.8000  67.38
# 2470328     AA    367153  2018-03-01  45.93  44.5800  46.4400  45.07
# 359981     AAL     68568  2018-03-01  54.14  53.2995  55.3100  53.48
# 3047517    AAN    441241  2018-03-01  46.09  45.2100  46.5200  46.45
# 4061239   AAOI    671827  2018-03-01  27.90  27.1112  28.2000  27.82
# ...        ...       ...         ...    ...      ...      ...    ...
# 2941167    ZTS    378251  2018-03-01  80.86  79.8300  81.5700  80.44
# 106306    ZUMZ     45730  2018-03-01  19.65  19.1000  20.0000  19.70
# 4928403   ZYNE    901704  2018-03-01   9.71   9.5100   9.8003   9.68
# 1285113   ZYXI    171401  2018-03-01   3.70   3.7000   4.3000   3.95
# 1435607    low    186050  2018-03-01  89.57  87.1100  89.7000  87.96
#
#          Adj. Close  Dividend    Volume
# 109399        66.03       NaN   2401795
# 2470328       45.07       NaN   6501728
# 359981        52.23       NaN   5895581
# 3047517       46.11       NaN    601754
# 4061239       27.82       NaN   1138200
# ...             ...       ...       ...
# 2941167       79.47       NaN   3010275
# 106306        19.70       NaN    357290
# 4928403        9.68       NaN    195600
# 1285113        3.95       NaN     37918
# 1435607       84.61       NaN  15153351
#
# [1651 rows x 10 columns]

# %%
# Do the same in the opposite direction. 
Income_Data_2018 = ??[Income_Data_2018['Ticker'].??(??['?'])]
Incme_D?_201?
# Out:
#       Ticker  SimFinId Currency  Fiscal Year Fiscal Period Report Date  \
# 9          A     45846      USD         2017            FY  2017-10-31
# 13        AA    367153      USD         2017            FY  2017-12-31
# 24       AAL     68568      USD         2017            FY  2017-12-31
# 34       AAN    441241      USD         2017            FY  2017-12-31
# 41      AAOI    671827      USD         2017            FY  2017-12-31
# ...      ...       ...      ...          ...           ...         ...
# 15082    ZTS    378251      USD         2017            FY  2017-12-31
# 15090   ZUMZ     45730      USD         2017            FY  2018-02-28
# 15104   ZYNE    901704      USD         2017            FY  2017-12-31
# 15113   ZYXI    171401      USD         2017            FY  2017-12-31
# 15124    low    186050      USD         2017            FY  2018-02-28
#
#       Publish Date  Shares (Basic)  Shares (Diluted)       Revenue  ...  \
# 9       2017-12-21     322000000.0       326000000.0  4.472000e+09  ...
# 13      2018-02-26     184000000.0       187000000.0  1.165200e+10  ...
# 24      2018-02-21     489164000.0       491692000.0  4.220700e+10  ...
# 34      2018-03-01      70837000.0        72121000.0  3.383708e+09  ...
# 41      2018-02-28      19097355.0        20139105.0  3.823290e+08  ...
# ...            ...             ...               ...           ...  ...
# 15082   2018-02-15     489918000.0       493161000.0  5.307000e+09  ...
# 15090   2018-03-19      24679000.0        24878000.0  9.274010e+08  ...
# 15104   2018-03-12      12914814.0        12914814.0  0.000000e+00  ...
# 15113   2018-02-28      32156000.0        33196000.0  2.343200e+07  ...
# 15124   2018-04-02     839000000.0       840000000.0  6.861900e+10  ...
#
#        Non-Operating Income (Loss)  Interest Expense, Net  \
# 9                      -38000000.0            -57000000.0
# 13                     -46000000.0           -104000000.0
# 24                    -974000000.0           -959000000.0
# 34                     -15122000.0            -18703000.0
# 41                      -2425000.0              -637000.0
# ...                            ...                    ...
# 15082                 -181000000.0           -175000000.0
# 15090                    -357000.0               495000.0
# 15104                     810705.0               519554.0
# 15113                   -1450000.0             -1450000.0
# 15124                 -633000000.0           -633000000.0
#
#        Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  \
# 9                       803000000                      NaN
# 13                     1468000000             -309000000.0
# 24                     3084000000                      NaN
# 34                      257571000              -17994000.0
# 41                       84526000                      NaN
# ...                           ...                      ...
# 15082                  1544000000              -19000000.0
# 15090                    48403000                      NaN
# 15104                   -32012304                      0.0
# 15113                     7494000                      NaN
# 15124                  5953000000             -464000000.0
#
#        Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 9                 803000000                      -1.190000e+08
# 13               1159000000                      -6.000000e+08
# 24               3084000000                      -1.165000e+09
# 34                239577000                       5.295900e+07
# 41                 84526000                      -1.057500e+07
# ...                     ...                                ...
# 15082            1525000000                      -6.630000e+08
# 15090              48403000                      -2.160100e+07
# 15104             -32012304                       0.000000e+00
# 15113               7494000                      -1.290000e+05
# 15124            5489000000                      -2.042000e+09
#
#        Income (Loss) from Continuing Operations  \
# 9                                     684000000
# 13                                    559000000
# 24                                   1919000000
# 34                                    292536000
# 41                                     73951000
# ...                                         ...
# 15082                                 862000000
# 15090                                  26802000
# 15104                                 -32012304
# 15113                                   7365000
# 15124                                3447000000
#
#        Net Extraordinary Gains (Losses)  Net Income  Net Income (Common)
# 9                                   NaN   684000000            684000000
# 13                                  NaN   217000000            217000000
# 24                                  NaN  1919000000           1919000000
# 34                                  NaN   292536000            292536000
# 41                                  NaN    73951000             73951000
# ...                                 ...         ...                  ...
# 15082                               NaN   864000000            864000000
# 15090                               NaN    26802000             26802000
# 15104                               NaN   -32012304            -32012304
# 15113                               NaN     7365000              7365000
# 15124                               NaN  3447000000           3447000000
#
# [1651 rows x 27 columns]

# %%
# We have lost some rows in our dataframes in keeping only common stock tickers. Sometimes we lose things, such is life.
# Arrange both income and stock price dataframes alphabetically so the rows correspond.
# Create a new dataframe called stock_data_2018 as a copy of Income_Data_2018 (we will be adding some columns soon)
# Create a market cap column in stock_data_2018 by multiplying the open price with the number of shares outstanding,
# use .values to do the multiplication.

stock_prices_2018 = stock_prices_2018.sort_values(by=['Ticker'])
Income_Data_2018 = Income_Data_2018.??(by=['??'])

# Make the stock_data DataFrame from the Income Data and add a Market Cap series.
stock_data_2018 = Income_Data_???
stock_data_2018['Market Cap'] = Income_Data_2018['Shares (Diluted)'].?? * stock_prices_2018['Open'].values

# %%
# Take a look at the distribution of Market Caps in the stock market with a histogram.
# use a large number of hisogram bins and a log scale, this will enable you to view the data better.
# You will see that there are many at the low end, and very few super large corporations in America

stock_data_2018['Market Cap'].hist(bins=100, log=True)
# Try to format this graph yourself with title, axis labels and so on.

# %% [markdown]
# ## Using market cap, make a price/earnings Series in the Stock_Data DataFrame

# %%
# Define a new column for price/earnings
# and view the histogram for it

stock_data_2018['Price/Earnings'] = ???['Market Cap']/stock_data_2018['Net Income']
stock_data_2018['Price/Earnings'].hist(bins=100, log=True)
# Notice that there are values all over the place 
# some p/e ratios are above 10,000! and there are many below 0 (they don't earn eanything!)

# %% [markdown]
# # Filter your stock data
# Filter your stock data for a reasonable range of price/earnings ratios of companies you might invest in, say from 5 to 50, and look at the histogram of the resulting companies.
# You may need to use a boolean list with some logic to do so.

# %%
# Make the same histogram as before for p/e but this time after a filter by p/e above 5 and below 50.
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (????['Price/Earnings'] <= 50))]['Price/Earnings'].hist(

# %%
#View a histogram of a different column, say market cap, but with the same p/e filter
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (stock_data_2018['Price/Earnings'] <= 50))]['???'].hist(log=True)

# %%
# You can also plot scatter plots with Pandas, here is an example scatter plot of p/e with Market cap.
# It appears as though the largest companies have a p/e around 20-35, for the rest nearly any p/e can be found.
stock_data_2018[((stock_data_2018['Price/Earnings'] >= 5) & (stock_data_2018['Price/Earnings'] <= 50))].plot.scatter(x = 'Price/Earnings', y = 'Market Cap')

# %% [markdown]
# End of Exercise 6. With the tools you have you are now able to use Pandas to filter through fundamental stock data. There are a myriad of ratios and analyses that may be carried out to filter through stocks to find good investments. In the next chapter we will learn some basics of Machine Learning to try and sift through data and find useful infomation.
